# %% [markdown]
# ## 31 done

# %%
def dfs(graph, visited, now):
  visited[now] = 1  # True
  for neig in graph[now]:
    if not visited[neig]:
      dfs(graph, visited, neig)

n, m = map(int, input().split())
graph = [list() for _ in range(n + 1)]
visited = [0] * (n + 1)

for _ in range(m):
  v_1, v_2 = map(int, input().split())
  if v_2 not in graph[v_1]:
    graph[v_1].append(v_2)

dfs(graph, visited, 1)
# Out:
# 3 4

# %% [markdown]
# ## 32 done

# %%
from threading import stack_size
from sys import setrecursionlimit


setrecursionlimit(1_000_000)
stack_size(134_217_728)

def dfs(graph, visited, now, comp):
    visited[now] = comp  # True
    for neig in graph[now]:
        if not visited[neig]:
            dfs(graph, visited, neig, comp)

with open('input.txt', 'r') as f_in:
    n, m = map(int, f_in.readline().strip().split())
    graph = [list() for _ in range(n + 1)]
#     graph = [list()] * (n + 1)
    visited = [0] * (n + 1)

    for _ in range(m):
        v_1, v_2 = map(int, f_in.readline().split())
        if v_2 not in graph[v_1]:
            graph[v_1].append(v_2)
        if v_1 not in graph[v_2]:
            graph[v_2].append(v_1)
                   
    comp = 1
    for i in range(1, n + 1):
        if not visited[i]:
            dfs(graph, visited, i, comp)
            comp += 1
            
    print(comp - 1)
    for i in range(1, comp):
        comp_lst = [x for x in range(n + 1) if visited[x] == i]
#         print("\n".join([str(len(comp_lst)), " ".join(map(str, comp_lst))]))
        print(len(comp_lst))
        print(" ".join(map(str, comp_lst)))

# %% [markdown]
# ## 33

# %% [markdown]
# ## 34

# %% [markdown]
# ## 35
