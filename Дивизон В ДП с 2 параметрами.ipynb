# %% [markdown]
# ## 26

# %%
with open('input.txt', 'r') as f_in:
  n, m = map(int, f_in.readline().split())
  a = [[int(x) for x in f_in.readline().split()] for _ in range(n)]
  # print(table)
  dp = [[1001 for _ in range(m + 1)] for _ in range(n + 1)]
  dp[1][1] = a[0][0]
  # print(dp)
  for i in range(1, n + 1):
    for j in range(1, m + 1):
      if not (i == j == 1):
        dp[i][j] = min(dp[i - 1][j], dp[i][j - 1]) + a[i - 1][j - 1]
    # for i in range(n + 1):
    #   print(dp[i])
    # print()
  print(dp[n][m])
# Out:
# 108

# %% [markdown]
# ## 27

# %%
with open('input.txt', 'r') as f_in:
  n, m = map(int, f_in.readline().split())
  a = [[int(x) for x in f_in.readline().split()] for _ in range(n)]
  # print(table)
  dp = [[0 for _ in range(m + 1)] for _ in range(n + 1)]
  prev = [[[-1, -1] for _ in range(m + 1)] for _ in range(n + 1)]
  dp[1][1] = a[0][0]
  # print(dp)
  for i in range(1, n + 1):
    for j in range(1, m + 1):
      if not (i == j == 1):
        dp[i][j] = max(dp[i - 1][j], dp[i][j - 1]) + a[i - 1][j - 1]
        if dp[i - 1][j] >= dp[i][j - 1]:
          prev[i][j][0] = i - 1
          prev[i][j][1] = j
          # prev[i][j][0] = i
          # prev[i][j][1] = j + 1
        else:
          prev[i][j][0] = i
          prev[i][j][1] = j - 1
          # prev[i][j][0] = i + 1
          # prev[i][j][1] = j
    # for i in range(n + 1):
    #   print(dp[i])
    # print()
    # for i in range(n + 1):
    #   print(prev[i])
    # print()
  # print(prev)
  i, j = n, m
  ans_lst = []
  while i > -1:
    # print(i, j)
    # print(prev[i][j])
    if i > prev[i][j][0]:
      ans_lst.append("D")
      # i = prev[i][j][0]
    else:
      ans_lst.append("R")
      # j = prev[i][j][1]
    i, j = prev[i][j]
  print(dp[n][m])
  print(" ".join(map(str, ans_lst[-2::-1])))
  # print(ans_lst[-3])
# Out:
# 0
# D D D D

# %% [markdown]
# ## 28

# %%
n, m = map(int, input().split())
dp = [[0 for _ in range(m + 2)] for _ in range(n + 2)]
dp[1][1] = 1
for i in range(2, n + 2):
  for j in range(2, m + 2):
    dp[i][j] = dp[i - 1][j - 2] + dp[i - 2][j - 1]
  # for i in range(n + 1):
  #   print(dp[i])
  # print()
print(dp[n][m])
# Out:
# 2 3
# 1

# %% [markdown]
# ## 29

# %%
with open('input.txt', 'r') as f_in:
  n = int(f_in.readline())
  a = [int(f_in.readline()) for _ in range(n)]
  max_val = 300 * 100 + 1
  dp = [[max_val for _ in range(n + 1)] for _ in range(n + 1)]
  dp[0][0] = 0
  # n_coupon = 0
  for i in range(1, n):
    for j in range(n):
      if a[i] > 100:
        dp[i][j] = min(dp[i - 1][j - 1] + a[i] if i > 0 and j > 0 else max_val, dp[i - 1][j + 1] if i > 0 and j < n - 1 else max_val)
      else:
        # print(i, j)
        dp[i][j] = min(dp[i - 1][j] + a[i] if i > 0 else max_val, dp[i - 1][j + 1] if i > 0 and j < n - 1 else max_val)
    print(dp)
# Out:
# [[0, 30001, 30001, 30001, 30001, 30001], [40, 30001, 30001, 30001, 30001, 30001], [30001, 30001, 30001, 30001, 30001, 30001], [30001, 30001, 30001, 30001, 30001, 30001], [30001, 30001, 30001, 30001, 30001, 30001], [30001, 30001, 30001, 30001, 30001, 30001]]
# [[0, 30001, 30001, 30001, 30001, 30001], [40, 30001, 30001, 30001, 30001, 30001], [30001, 141, 30001, 30001, 30001, 30001], [30001, 30001, 30001, 30001, 30001, 30001], [30001, 30001, 30001, 30001, 30001, 30001], [30001, 30001, 30001, 30001, 30001, 30001]]
# [[0, 30001, 30001, 30001, 30001, 30001], [40, 30001, 30001, 30001, 30001, 30001], [30001, 141, 30001, 30001, 30001, 30001], [141, 200, 30001, 30001, 30001, 30001], [30001, 30001, 30001, 30001, 30001, 30001], [30001, 30001, 30001, 30001, 30001, 30001]]
# ...

# %% [markdown]
# ## 30

# %%
with open('input.txt', 'r') as f_in:
  n = int(f_in.readline())
  seq_1 = list(map(int, f_in.readline().split()))
  m = int(f_in.readline())
  seq_2 = list(map(int, f_in.readline().split()))
  # n = 5
  # seq_1 = [0, 1, 2, 0, 1]
  # m = 6
  # seq_2 = [3, 2, 0, 2, 2, 1]

  dp = [[0 for _ in range(m + 1)] for _ in range(n + 1)]
  for i in range(1, n + 1):
    for j in range(1, m + 1):
      if seq_1[i - 1] == seq_2[j - 1]:
        dp[i][j] = dp[i - 1][j - 1] + 1
      else:
        dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
  # print(dp[n][m])
  # print(i, j)
  subseq = [0 for _ in range(dp[n][m])]
  subseq_index = 0
  while i > 0 and j > 0:
    if seq_1[i - 1] == seq_2[j - 1]:
        subseq[subseq_index] = seq_1[i - 1]
        subseq_index += 1
        i -= 1
        j -= 1
    elif dp[i - 1][j] == dp[i][j]:
        i -= 1 
    else: 
        j -= 1 
  print(' '.join(map(str, subseq[::-1])))
# Out:
# 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 
# ...

# %%
cor_ans = '2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2 3 4 2 2 3 4 2 3 4 2'

# %%
len(subseq)
# Out:
# 997

# %%
subseq_str = ' '.join(map(str, subseq[::-1]))

# %%
len(subseq_str)
# Out:
# 1993

# %%
len(cor_ans)
# Out:
# 1993

# %%
subseq_str == cor_ans
# Out:
# True

# %%
cor_ans[896 * 2]
# Out:
# '2'

# %%
subseq[896]
# Out:
# 2

# %%
for i in range(len(subseq_str)):
  if subseq_str[i] != cor_ans[i]:
    print(subseq_str[i], cor_ans[i], i // 2)

# %%
dp[n][m]
# Out:
# 997

# %%
i
# Out:
# 1992

# %%
j
# Out:
# 0

# %%
dp
# Out:
# Output hidden; open in https://colab.research.google.com to view.
