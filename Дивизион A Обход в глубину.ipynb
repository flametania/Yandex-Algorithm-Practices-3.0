# %% [markdown]
# ## 31 done

# %%
def dfs(graph, i, j, cnt):
  if (graph[i][j] == '*'):
    # print(cnt)
    return
  cnt[0] += 1
  # print(graph[i][j], cnt)
  graph[i][j] = '*'
  dfs(graph, i - 1, j, cnt)
  dfs(graph, i + 1, j, cnt)
  dfs(graph, i, j - 1, cnt)
  dfs(graph, i, j + 1, cnt)

with open('input.txt', 'r') as f_in:
  n = int(f_in.readline())
  graph = [["*" for _ in range(n + 1)] for _ in range(n + 1)]
  visited = [0] * (n + 1)
  for x in range(1, n + 1):
    # print(x)
    s = f_in.readline().strip()
    # print(s)
    for y in range(len(s)):
      # print(y)
      graph[x][y + 1] = s[y]
  # print(graph)

  i, j = map(int, f_in.readline().split())
  # print(graph[i][j], i, j)

  cnt = [0]
  dfs(graph, i, j, cnt)

  print(cnt[0])
# Out:
# 4

# %% [markdown]
# ## 32 done

# %%
# from threading import stack_size
# from sys import setrecursionlimit


# setrecursionlimit(1_000_000)
# stack_size(134_217_728)

def dfs(graph, visited, now):
    visited[now] = 1  # True
    for neig in graph[now]:
        if not visited[neig]:
            dfs(graph, visited, neig)

with open('input.txt', 'r') as f_in:
    n, m = map(int, f_in.readline().strip().split())
    graph = [list() for _ in range(n + 1)]
#     graph = [list()] * (n + 1)
    visited = [0] * (n + 1)

    for _ in range(m):
        v_1, v_2 = map(int, f_in.readline().split())
        # if v_2 not in graph[v_1]:
        #     graph[v_1].append(v_2)
        if v_1 not in graph[v_2]:
            graph[v_2].append(v_1)
                   
    dfs(graph, visited, 1)

    comp_lst = [x for x in range(n + 1) if visited[x] == 1]
    print(" ".join(map(str, comp_lst)))
# Out:
# 1 2 3 4

# %% [markdown]
# ## 33

# %% [markdown]
# ## 34

# %% [markdown]
# ## 35
